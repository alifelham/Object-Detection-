# %% [markdown]
# ##SETUP

# %%
import torch
import numpy as np
from matplotlib import pyplot as plt

# %%
# %%capture
# !git clone https://github.com/ultralytics/yolov5.git
# %cd /content/yolov5
# !pip install -r requirements.txt

# %% [markdown]
# ## LOADING MODEL

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-9-15 Python-3.7.13 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# ## DETECTION

# %%
img = 'https://images.unsplash.com/photo-1589828155685-83225f7d91f3?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxzZWFyY2h8Nnx8Y2FyJTIwcm9hZHxlbnwwfHwwfHw%3D&w=1000&q=80'

# %% [markdown]
# ![traffic.jpeg](data:image/jpeg;base64,...)

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 1418x1000 3 persons, 26 cars, 1 motorcycle, 1 bus, 2 trucks
# Speed: 275.1ms pre-process, 325.1ms inference, 1.9ms NMS per image at shape (1, 3, 640, 480)

# %% [markdown]
# The model detects 3 persons, 26 cars, 1 motorcycle, 1 bus, and 2 trucks from the given image.

# %%
# %matplotlib inline
from matplotlib.pyplot import figure
figure(figsize = (20, 15))
plt.imshow(np.squeeze(results.render()))
plt.show()
